# %% [markdown]
# <a href="https://colab.research.google.com/github/Saponjyan/CV/blob/main/rrrrrrppp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/s0md3v/roop
# !pip install -r roop/requirements.txt
# !python roop/run.py
# Out:
# Cloning into 'roop'...
# remote: Enumerating objects: 1435, done.
# remote: Counting objects: 100% (1435/1435), done.
# remote: Compressing objects: 100% (578/578), done.
# remote: Total 1435 (delta 880), reused 1339 (delta 816), pack-reused 0
# Receiving objects: 100% (1435/1435), 90.72 MiB | 16.53 MiB/s, done.
# Resolving deltas: 100% (880/880), done.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Ignoring torch: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring torchvision: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring onnxruntime: markers 'sys_platform == "darwin" and platform_machine != "arm64"' don't match your environment
# Ignoring onnxruntime-silicon: markers 'sys_platform == "darwin" and platform_machine == "arm64"' don't match your environment
# Ignoring tensorflow: markers 'sys_platform == "darwin"' don't match your environment
# Collecting numpy==1.23.5 (from -r roop/requirements.txt (line 3))
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 37.9 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python==4.7.0.72 in /usr/local/lib/python3.10/dist-packages (from -r roop/requirements.txt (line 4)) (4.7.0.72)
# Collecting onnx==1.14.0 (from -r roop/requirements.txt (line 5))
#   Downloading onnx-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 59.7 MB/s eta 0:00:00
# Collecting insightface==0.7.3 (from -r roop/requirements.txt (line 6))
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 35.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: psutil==5.9.5 in /usr/local/lib/python3.10/dist-packages (from -r roop/requirements.txt (line 7)) (5.9.5)
# Collecting tk==0.1.0 (from -r roop/requirements.txt (line 8))
#   Downloading tk-0.1.0-py3-none-any.whl (3.9 kB)
# Collecting customtkinter==5.1.3 (from -r roop/requirements.txt (line 9))
#   Downloading customtkinter-5.1.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 19.9 MB/s eta 0:00:00
# Collecting pillow==9.5.0 (from -r roop/requirements.txt (line 10))
#   Downloading Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 50.7 MB/s eta 0:00:00
# Requirement already satisfied: torch==2.0.1+cu118 in /usr/local/lib/python3.10/dist-packages (from -r roop/requirements.txt (line 11)) (2.0.1+cu118)
# Requirement already satisfied: torchvision==0.15.2+cu118 in /usr/local/lib/python3.10/dist-packages (from -r roop/requirements.txt (line 13)) (0.15.2+cu118)
# Collecting onnxruntime-gpu==1.15.0 (from -r roop/requirements.txt (line 17))
#   Downloading onnxruntime_gpu-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (122.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.2/122.2 MB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.10/dist-packages (from -r roop/requirements.txt (line 19)) (2.12.0)
# Collecting opennsfw2==0.10.2 (from -r roop/requirements.txt (line 20))
#   Downloading opennsfw2-0.10.2-py3-none-any.whl (12 kB)
# Collecting protobuf==4.23.2 (from -r roop/requirements.txt (line 21))
#   Downloading protobuf-4.23.2-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 26.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm==4.65.0 in /usr/local/lib/python3.10/dist-packages (from -r roop/requirements.txt (line 22)) (4.65.0)
# Collecting gfpgan==1.3.8 (from -r roop/requirements.txt (line 23))
#   Downloading gfpgan-1.3.8-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx==1.14.0->-r roop/requirements.txt (line 5)) (4.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (2.27.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.11.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (0.19.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.10)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (0.29.36)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3->-r roop/requirements.txt (line 6)) (0.7.2)
# Collecting darkdetect (from customtkinter==5.1.3->-r roop/requirements.txt (line 9))
#   Downloading darkdetect-0.8.0-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (2.0.0)
# Collecting coloredlogs (from onnxruntime-gpu==1.15.0->-r roop/requirements.txt (line 17))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu==1.15.0->-r roop/requirements.txt (line 17)) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu==1.15.0->-r roop/requirements.txt (line 17)) (23.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (0.3.25)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (0.32.0)
# Requirement already satisfied: gdown>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from opennsfw2==0.10.2->-r roop/requirements.txt (line 20)) (4.6.6)
# Collecting basicsr>=1.4.2 (from gfpgan==1.3.8->-r roop/requirements.txt (line 23))
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 15.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting facexlib>=0.2.5 (from gfpgan==1.3.8->-r roop/requirements.txt (line 23))
#   Downloading facexlib-0.3.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.1 MB/s eta 0:00:00
# Collecting lmdb (from gfpgan==1.3.8->-r roop/requirements.txt (line 23))
#   Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from gfpgan==1.3.8->-r roop/requirements.txt (line 23)) (6.0)
# Collecting tb-nightly (from gfpgan==1.3.8->-r roop/requirements.txt (line 23))
#   Downloading tb_nightly-2.14.0a20230713-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 80.1 MB/s eta 0:00:00
# Collecting yapf (from gfpgan==1.3.8->-r roop/requirements.txt (line 23))
#   Downloading yapf-0.40.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (16.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (0.40.0)
# Collecting addict (from basicsr>=1.4.2->gfpgan==1.3.8->-r roop/requirements.txt (line 23))
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.4.2->gfpgan==1.3.8->-r roop/requirements.txt (line 23)) (0.18.3)
# Collecting filterpy (from facexlib>=0.2.5->gfpgan==1.3.8->-r roop/requirements.txt (line 23))
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from facexlib>=0.2.5->gfpgan==1.3.8->-r roop/requirements.txt (line 23)) (0.56.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.2.0->opennsfw2==0.10.2->-r roop/requirements.txt (line 20)) (4.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3->-r roop/requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3->-r roop/requirements.txt (line 6)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3->-r roop/requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3->-r roop/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface==0.7.3->-r roop/requirements.txt (line 6)) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface==0.7.3->-r roop/requirements.txt (line 6)) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (2.3.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->insightface==0.7.3->-r roop/requirements.txt (line 6)) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->insightface==0.7.3->-r roop/requirements.txt (line 6)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->insightface==0.7.3->-r roop/requirements.txt (line 6)) (3.4)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations->insightface==0.7.3->-r roop/requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations->insightface==0.7.3->-r roop/requirements.txt (line 6)) (4.8.0.74)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu==1.15.0->-r roop/requirements.txt (line 17))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (2.1.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->insightface==0.7.3->-r roop/requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1+cu118->-r roop/requirements.txt (line 11)) (1.3.0)
# Collecting importlib-metadata>=6.6.0 (from yapf->gfpgan==1.3.8->-r roop/requirements.txt (line 23))
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->gfpgan==1.3.8->-r roop/requirements.txt (line 23)) (3.8.1)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->gfpgan==1.3.8->-r roop/requirements.txt (line 23)) (2.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->gfpgan==1.3.8->-r roop/requirements.txt (line 23)) (3.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.2.0->opennsfw2==0.10.2->-r roop/requirements.txt (line 20)) (2.4.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->facexlib>=0.2.5->gfpgan==1.3.8->-r roop/requirements.txt (line 23)) (0.39.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->insightface==0.7.3->-r roop/requirements.txt (line 6)) (1.7.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0->-r roop/requirements.txt (line 19)) (3.2.2)
# Building wheels for collected packages: insightface, basicsr, filterpy
#   Building wheel for insightface (pyproject.toml) ... done
#   Created wheel for insightface: filename=insightface-0.7.3-cp310-cp310-linux_x86_64.whl size=1054603 sha256=3339625015b4dc2694d546f0941d7601229c17171cf7818e9bfac54c30e1a047
#   Stored in directory: /root/.cache/pip/wheels/e3/d0/80/e3773fb8b6d1cca87ea1d33d9b1f20a223a6493c896da249b5
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214822 sha256=3ceea5bd329bf389d999e7adc21206a8a17129ec35a0c475142fbcab624344e7
#   Stored in directory: /root/.cache/pip/wheels/38/83/99/2d8437cc652a01af27df5ff037a4075e95b52d67705c5f30ca
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110459 sha256=97cee165917b8faaed87af6d58de2565edde83ddfdd7843c824b6d7d2daf66f0
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
# Successfully built insightface basicsr filterpy
# Installing collected packages: tk, lmdb, addict, protobuf, pillow, numpy, importlib-metadata, humanfriendly, darkdetect, yapf, onnx, customtkinter, coloredlogs, onnxruntime-gpu, tb-nightly, filterpy, opennsfw2, insightface, facexlib, basicsr, gfpgan
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.1
#     Uninstalling numpy-1.25.1:
#       Successfully uninstalled numpy-1.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.7 requires jax>=0.4.6, but you have jax 0.3.25 which is incompatible.
# flax 0.7.0 requires jax>=0.4.2, but you have jax 0.3.25 which is incompatible.
# orbax-checkpoint 0.2.7 requires jax>=0.4.9, but you have jax 0.3.25 which is incompatible.
# Successfully installed addict-2.4.0 basicsr-1.4.2 coloredlogs-15.0.1 customtkinter-5.1.3 darkdetect-0.8.0 facexlib-0.3.0 filterpy-1.4.5 gfpgan-1.3.8 humanfriendly-10.0 importlib-metadata-6.8.0 insightface-0.7.3 lmdb-1.4.1 numpy-1.23.5 onnx-1.14.0 onnxruntime-gpu-1.15.0 opennsfw2-0.10.2 pillow-9.5.0 protobuf-4.23.2 tb-nightly-2.14.0a20230713 tk-0.1.0 yapf-0.40.1

# %%
# usage: run.py
#        [-h]
#        [-s SOURCE_PATH]
#        [-t TARGET_PATH]
#        [-o OUTPUT_PATH]
#        [--frame-processor FRAME_PROCESSOR [FRAME_PROCESSOR ...]]
#        [--keep-fps]
#        [--keep-audio]
#        [--keep-frames]
#        [--many-faces]
#        [--video-encoder {libx264,libx265,libvpx-vp9}]
#        [--video-quality [0-51]]
#        [--max-memory MAX_MEMORY]
#        [--execution-provider {tensorrt,cuda,cpu} [{tensorrt,cuda,cpu} ...]]
#        [--execution-threads EXECUTION_THREADS]
#        [-v]
# run.py: error: argument --execution-provider: invalid choice: 'tensor' (choose from 'tensorrt', 'cuda', 'cpu')
# gpu 10min
# !python roop/run.py -s foto.jpg -t a2.mp4 -o dat --execution-provider cuda
# Out:
# EP Error /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, ERRTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; std::conditional_t<THRW, void, onnxruntime::common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:114 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, ERRTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; std::conditional_t<THRW, void, onnxruntime::common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=-1511146496 ; hostname=5a8182a6a3fe ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=238 ; expr=cudaSetDevice(info_.device_id);
#
#  when using ['CUDAExecutionProvider']
# Falling back to ['CUDAExecutionProvider', 'CPUExecutionProvider'] and retrying.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 383, in __init__
#     self._create_inference_session(providers, provider_options, disabled_optimizers)
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 435, in _create_inference_session
#     sess.initialize_session(providers, provider_options, disabled_optimizers)
# RuntimeError: /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, ERRTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; std::conditional_t<THRW, void, onnxruntime::common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:114 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, ERRTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; std::conditional_t<THRW, void, onnxruntime::common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=-1511146496 ; hostname=5a8182a6a3fe ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=238 ; expr=cudaSetDevice(info_.device_id);
#
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/roop/run.py", line 6, in <module>
#     core.run()
#   File "/content/roop/roop/core.py", line 212, in run
#     start()
#   File "/content/roop/roop/core.py", line 141, in start
#     if not frame_processor.pre_start():
#   File "/content/roop/roop/processors/frame/face_swapper.py", line 38, in pre_start
#     elif not get_one_face(cv2.imread(roop.globals.source_path)):
#   File "/content/roop/roop/face_analyser.py", line 23, in get_one_face
#     face = get_face_analyser().get(frame)
#   File "/content/roop/roop/face_analyser.py", line 17, in get_face_analyser
#     FACE_ANALYSER = insightface.app.FaceAnalysis(name='buffalo_l', providers=roop.globals.execution_providers)
#   File "/usr/local/lib/python3.10/dist-packages/insightface/app/face_analysis.py", line 31, in __init__
#     model = model_zoo.get_model(onnx_file, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/insightface/model_zoo/model_zoo.py", line 96, in get_model
#     model = router.get_model(providers=providers, provider_options=provider_options)
#   File "/usr/local/lib/python3.10/dist-packages/insightface/model_zoo/model_zoo.py", line 40, in get_model
#     session = PickableInferenceSession(self.onnx_file, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/insightface/model_zoo/model_zoo.py", line 25, in __init__
#     super().__init__(model_path, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 394, in __init__
#     raise fallback_error from e
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 389, in __init__
#     self._create_inference_session(self._fallback_providers, None)
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 435, in _create_inference_session
#     sess.initialize_session(providers, provider_options, disabled_optimizers)
# RuntimeError: /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, ERRTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; std::conditional_t<THRW, void, onnxruntime::common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:114 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, ERRTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; std::conditional_t<THRW, void, onnxruntime::common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=1594326651 ; hostname=5a8182a6a3fe ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=238 ; expr=cudaSetDevice(info_.device_id);
